# %%
import pandas as pd
import dash_bio

# %%
df = pd.read_csv('https://git.io/volcano_data1.csv')

# %%
df
# Out:
#       CHR         BP         P         SNP  ZSCORE  EFFECTSIZE     GENE  \
# 0       1     937641  0.335344   rs9697358  0.9634     -0.0946    ISG15
# 1       1    1136887  0.245857  rs34945898  1.1605     -0.0947  TNFRSF4
# 2       1    2116240  0.823286  rs12034613  0.2233     -0.0741   FP7162
# 3       1    2310562  0.493204   rs4648633  0.6852      0.0146    MORN1
# 4       1    2681715  0.605392   rs4430271  0.5167      0.1234    MMEL1
# ...   ...        ...       ...         ...     ...         ...      ...
# 9929   23  153207974  0.574920    rs766418  0.5608     -0.0190      NaN
# 9930   23  153280339  0.978400     rs11593  0.0271     -0.1355      NaN
# 9931   23  153546061  0.056012   rs5987005  1.9109      0.0026      NaN
# 9932   23  153903746  0.132189  rs28370194  1.5055     -0.1425      NaN
# 9933   23  154208789  0.497909    rs524609  0.6778      0.2542      NaN
#
#       DISTANCE
# 0         1068
# 1            0
# 2            0
# 3            0
# 4       127427
# ...

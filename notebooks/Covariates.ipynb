# %%
import scipy as scp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import csv
covariates=pd.read_csv("../data/covariates.csv")

# %%
covariates
# Out:
#      Unnamed: 0    Participant_ID         GUID    NYGC CGND ID Genomics  \
# 0             0  CASE-NEUDE902GCT  NEUDE902GCT  CGND-HDA-01358      Yes
# 1             1  CTRL-NEUAA485DZL  NEUAA485DZL  CGND-HDA-03103      Yes
# 2             2  CASE-NEUAA599TMX  NEUAA599TMX  CGND-HDA-00461      Yes
# 3             3  CASE-NEUAB000NKC  NEUAB000NKC  CGND-HDA-00583      Yes
# 4             4  CASE-NEUAE228FF6  NEUAE228FF6  CGND-HDA-02221      Yes
# ..          ...               ...          ...             ...      ...
# 285         285  CASE-NEUZW701NNF  NEUZW701NNF  CGND-HDA-01238      Yes
# 286         286  CASE-NEUZX521TKK  NEUZX521TKK  CGND-HDA-01130      Yes
# 287         287  CASE-NEUZX847VWV  NEUZX847VWV  CGND-HDA-00253      Yes
# 288         288  CASE-NEUZY128BJ2  NEUZY128BJ2             NaN      NaN
# 289         289  CASE-NEUZY975XKL  NEUZY975XKL  CGND-HDA-01338      Yes
#
#     Epigenomics Transcriptomics Proteomics  Number of Visits     Sex  ...  \
# ...

# %%
covariates['Case_Control'] =np.where(covariates['Participant_ID'].str.contains('CASE'), 'CASE', 'CONTROL')
covariates
# Out:
#        Participant_ID         GUID    NYGC CGND ID Genomics Epigenomics  \
# 0    CASE-NEUDE902GCT  NEUDE902GCT  CGND-HDA-01358      Yes         Yes
# 1    CTRL-NEUAA485DZL  NEUAA485DZL  CGND-HDA-03103      Yes         Yes
# 2    CASE-NEUAA599TMX  NEUAA599TMX  CGND-HDA-00461      Yes         Yes
# 3    CASE-NEUAB000NKC  NEUAB000NKC  CGND-HDA-00583      Yes         Yes
# 4    CASE-NEUAE228FF6  NEUAE228FF6  CGND-HDA-02221      Yes         Yes
# ..                ...          ...             ...      ...         ...
# 285  CASE-NEUZW701NNF  NEUZW701NNF  CGND-HDA-01238      Yes         Yes
# 286  CASE-NEUZX521TKK  NEUZX521TKK  CGND-HDA-01130      Yes         Yes
# 287  CASE-NEUZX847VWV  NEUZX847VWV  CGND-HDA-00253      Yes         Yes
# 288  CASE-NEUZY128BJ2  NEUZY128BJ2             NaN      NaN         Yes
# 289  CASE-NEUZY975XKL  NEUZY975XKL  CGND-HDA-01338      Yes         Yes
#
#     Transcriptomics Proteomics  Number of Visits     Sex  \
# ...

# %%
covariates.to_csv('../data/covariates.csv')
